# %% [markdown]
# <a href="https://colab.research.google.com/github/ram0ng1/Ciencia_de_Dados_Aprendizagem_Maquina/blob/main/Unidade2_Analise_e_Ciencia_de_Dados/datasciense.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### A**ula 02/09 _ II - Análise e Ciência de Dados**
# - Visualização e interpretação de dados
#
# - Aula prática + resolução colaborativa de problemas
# - Criar gráficos e interpretar informações obtidas dos dados
# - Dashboard ou conjunto de visualizações comentadas
#
#  *nome : Ramon Guilerme / Sistemas de Informação*
#
# *Referência: https://bonidia.github.io/cd-fundamentos/cp2.html.*
